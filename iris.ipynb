# %% [markdown]
# # Iris Classification :
#
# #Develop a ML Model for classifying iris flowers based on their features using Python, scikit-learn, and TensorFlow.

# %%
#Develop a ML Model for classifying iris flowers based on their features using Python

# Step 1: Load the Dataset
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target
species_map = {i: name for i, name in enumerate(iris.target_names)}
iris_df['species_name'] = iris_df['species'].map(species_map)
print(iris_df.head())

# Step 2: Explore and Preprocess the Data
print(iris_df.describe())
print(iris_df.isnull().sum())

# Step 3: Split the Data into Training and Testing Sets
from sklearn.model_selection import train_test_split

X = iris_df[iris.feature_names]
y = iris_df['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=34)

# Step 4: Train a Machine Learning Model
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=34)
model.fit(X_train, y_train)

# Step 5: Evaluate the Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(classification_report(y_test, y_pred))
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species species_name
# 0        0       setosa
# 1        0       setosa
# 2        0       setosa
# 3        0       setosa
# 4        0       setosa
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# species_name         0
# dtype: int64
# Accuracy: 0.9333333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.88      1.00      0.94        15
#            2       1.00      0.50      0.67         4
#
#     accuracy                           0.93        30
#    macro avg       0.96      0.83      0.87        30
# weighted avg       0.94      0.93      0.92        30
#
# Confusion Matrix:
# [[11  0  0]
#  [ 0 15  0]
#  [ 0  2  2]]

# %%
#Develop a ML Model for classifying iris flowers based on their features using scikit-learn

# Step 1: Load the Dataset
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target
print(iris_df.head())

# Step 2: Explore and Preprocess the Data
print(iris_df.describe())
print(iris_df.isnull().sum())

# Step 3: Split the Data into Training and Testing Sets
from sklearn.model_selection import train_test_split

X = iris_df[iris.feature_names]
y = iris_df['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=34)

# Step 4: Train a Machine Learning Model
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=34)
model.fit(X_train, y_train)

# Step 5: Evaluate the Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(classification_report(y_test, y_pred))
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64
# Accuracy: 0.9333333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.88      1.00      0.94        15
#            2       1.00      0.50      0.67         4
#
#     accuracy                           0.93        30
#    macro avg       0.96      0.83      0.87        30
# weighted avg       0.94      0.93      0.92        30
#
# Confusion Matrix:
# [[11  0  0]
#  [ 0 15  0]
#  [ 0  2  2]]

# %%
#Develop a ML Model for classifying iris flowers based on their features using TensorFlow

import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load the Iris dataset
iris = load_iris()

# Convert to DataFrame for better understanding
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target

# Features and target variable
X = iris_df[iris.feature_names].values
y = iris_df['species'].values

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=34)

# Convert to TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# Batch and shuffle the datasets
BATCH_SIZE = 32
train_dataset = train_dataset.shuffle(len(X_train)).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# Define the model
model = Sequential([
    Dense(10, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(10, activation='relu'),
    Dense(3, activation='softmax')  
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
EPOCHS = 50

history = model.fit(train_dataset, 
                    epochs=EPOCHS,
                    validation_data=test_dataset)

# Evaluate the model
loss, accuracy = model.evaluate(test_dataset)
print(f'Test accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/50
# C:\Users\Anusha\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - accuracy: 0.3021 - loss: 1.6053 - val_accuracy: 0.5000 - val_loss: 1.2197
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2927 - loss: 1.5142 - val_accuracy: 0.5000 - val_loss: 1.1690
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3302 - loss: 1.3358 - val_accuracy: 0.5000 - val_loss: 1.1294
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3031 - loss: 1.3178 - val_accuracy: 0.5000 - val_loss: 1.0962
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3021 - loss: 1.2508 - val_accuracy: 0.5000 - val_loss: 1.0695
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3167 - loss: 1.1677 - val_accuracy: 0.5000 - val_loss: 1.0485
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3000 - loss: 1.1688 - val_accuracy: 0.5000 - val_loss: 1.0304
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3177 - loss: 1.1084 - val_accuracy: 0.5000 - val_loss: 1.0169
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3010 - loss: 1.0720 - val_accuracy: 0.5000 - val_loss: 1.0068
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2927 - loss: 1.0388 - val_accuracy: 0.5000 - val_loss: 0.9988
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3000 - loss: 1.0217 - val_accuracy: 0.5000 - val_loss: 0.9908
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3010 - loss: 1.0090 - val_accuracy: 0.5000 - val_loss: 0.9822
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.